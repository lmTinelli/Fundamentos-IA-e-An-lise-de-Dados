# %%
print("Treinamento de IA para Análise de Dados")
# Out:
# Treinamento de IA para Análise de Dados

# %%
print("TINELLI")
# Out:
# TINELLI

# %%
# Célula de variáveis
nome = "LUIZ TINELLI"
print("O seu nome é",nome)
# Out:
# O seu nome é LUIZ TINELLI

# %%
print(f"SEU NOME: {nome}")
# Out:
# SEU NOME: LUIZ TINELLI

# %%
nome_sa = "LUIZ MARCELO TINELL"
idade_sa = 35
email_sa = "luizmarcelotinelli@gmail.com"
profissao_sa = "Estudante"

print(f"O seu nome é {nome_sa}")
print(f"Sua idade é {idade_sa} anos.")
print(f"Seu email é {email_sa}.")
print(f"Sua profissão é {profissao_sa}.")
# Out:
# O seu nome é LUIZ MARCELO TINELL
# Sua idade é 35 anos.
# Seu email é luizmarcelotinelli@gmail.com.
# Sua profissão é Estudante.

# %%
# Comparadores
comparador = 10 > 5     # Retorna True se for maior
print(comparador)
# Out:
# True

# %%
comparador = 5 < 10 # Retorna True se for menor
print(comparador)
# Out:
# True

# %%
comparador = (10 == 10) # Retorna True se forem iguais
print(comparador)
# Out:
# True

# %%
comparador = (10 != 5)  # Retorna True se foram diferentes
print(comparador)
# Out:
# True

# %%
temperatura = 100
if temperatura > 100:
    print("ALARME! O MOTOR ESTÁ FERVENDO!")
else:
    print("MOTOR EM TEMPERATURA IDEAL")
# Out:
# MOTOR EM TEMPERATURA IDEAL

# %% [markdown]
# Criar um script, que irá auxiliar os alunos do SENAI a saberem se devem ou não comprar um uniforme.
# Cursos acima de 40 horas, necessitam de uniforme.
# Cursos até 40 horas, necessitam do crachá.
# -Power BI: 32 horas.
# -IA  e Análise de Dados: 40 horas.
# -Eletricista Instalador: 160 horas.

# %%
# uniforme = 40
# nao_uniforme = 40
power_BI = 32
ia_AD = 40
eletricista_Instalador = 160

if power_BI > 40:
    print("Precisa usar UNIFORME!!!")

else:
    print("CRACHÁ NECESSÁRIO!!!")
# Out:
# CRACHÁ NECESSÁRIO!!!

# %%
if ia_AD > 40:
    print("Precisa usar UNIFORME!!!")
    
else:
    print("CRACHÁ NECESSÁRIO!!!")
# Out:
# CRACHÁ NECESSÁRIO!!!

# %%
if eletricista_Instalador > 40:
    print("Precisa usar UNIFORME!!!")
    
else:
    print("CRACHÁ NECESSÁRIO!!!")
# Out:
# Precisa usar UNIFORME!!!

# %% [markdown]
# Verificar a qualidade das notas de um aluno
# Maior do que 9: Excelente
# Maior do que 7: Boa
# Maior do que 5: Regular
# Abaixo de 5: Reprovado

# %%
# O comando input solicita a interação do usuário
nota = int(input("Digite a sua nota"))
print(nota)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # O comando input solicita a interação do usuário
# ----> 2 nota = int(input("Digite a sua nota"))
#       3 print(nota)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
if nota > 9:
    print("NOTA EXCELENTE")
elif nota > 7:
    print("NOTA BOA")
elif nota > 5:
    print("NOTA REGULAR")
else:
    print("REPROVADO")
# Out:
# NOTA EXCELENTE

# %%
# APP de um banco virtual
nome = input("Digite o seu nome: ")
print(f"Bem vindo {nome}.")
# Out:
# Bem vindo luk.

# %%
idade = int (input("Digite a sua idade: "))
print(idade)
print(type(idade))
# Out:
# 10
# <class 'int'>
